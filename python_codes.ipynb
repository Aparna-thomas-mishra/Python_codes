# %% [markdown]
# Introduction to Python

# %% [markdown]
# # Day 1 topics

# %%
# print hello world in python
# my first code
print('hello world')
# Out:
# hello world

# %%
print('hello \n world')
# Out:
# hello
#  world

# %%
# assessment
print('There once was a movie star icon\nwho preferred to sleep with the light on.\nThey learned how to code')
print('a device that sure glowed\nand lit up the night using Python!')
# Out:
# There once was a movie star icon
# who preferred to sleep with the light on.
# They learned how to code
# a device that sure glowed
# and lit up the night using Python!

# %%
#get input 
name = input("what is your name? \n")
print('Hello ' + name + '! Nice to meet you')
print(name.swapcase())
# Out:
# what is your name?
# Aparna
# Hello Aparna! Nice to meet you
# aPARNA

# %%
# Code with different functions
name = input('what is your name ')
print(name.count('a'))
print(name.capitalize())
print(name.replace('aparna',\
                   'appy'))
print(name.find('rna'))
# Out:
# what is your name aparna
# 3
# Aparna
# appy
# 3

# %%
# Find area of a rectangle. input values by users
length = input('Please enter the length of the rectangle ')
breadth = input('Please enter the breadth of the rectangle ')
area = float(length) * float(breadth)
print(area)
# Out:
# Please enter the length of the rectangle 3.56
# Please enter the breadth of the rectangle 4.87
# 17.3372

# %%
# Loan calculator
l= input('Enter loan amount ')
i= input('Enter Interest rate ')
n= input('Enter number of payments ')

c = 1+ float(i)
print(c)

m = float(l)*((float(i)*float(c)*float(n)) / (float(c)*float(n) -1))
print(m)
# Out:
# Enter loan amount 100
# Enter Interest rate 5
# Enter number of payments 12
# 6.0
# 507.0422535211268

# %%
import datetime

# print(datetime.date.today())
tday = datetime.date.today()
print(tday)
print(tday.day)
print(tday.month)
print(tday.year)
print(tday.strftime('%d/%b/%Y'))
# Out:
# 2023-05-12
# 12
# 5
# 2023
# 12/May/2023

# %% [markdown]
# https://babel.pocoo.org/en/latest/
# Internationalizing and localizing python applications\
#
#
# https://dateutil.readthedocs.io/en/stable/
# powerful extensions to datetime

# %%
# Calculate days till my bithday
import datetime

birthday = input('Enter your birthday (mm/dd/yyyy) ')
birthdate = datetime.datetime.strptime(birthday, "%m/%d/%Y").date()
print('Your birth month is ' + birthdate.strftime('%B'))
currentdate = datetime.date.today()
nextbirthday = datetime.datetime.strptime('12/15/2023','%m/%d/%Y').date()
difference = nextbirthday - currentdate
print(difference.days)
# Out:
# Enter your birthday (mm/dd/yyyy) 12/15/1992
# Your birth month is December
# 214

# %%
# print current time
import datetime

crntTime = datetime.datetime.now()
print(crntTime)
print(crntTime.hour)
print(crntTime.minute)
print(crntTime.second)
# Out:
# 2023-05-15 18:09:39.877786
# 18
# 9
# 39

# %%
# Ask user to input deadline date for a project. Display remaining time in days and weeks

import datetime
import math

prjtDeadline = input('Enter deadline for project (mm/dd/yyyy)')
prjtdate = datetime.datetime.strptime(prjtDeadline, "%m/%d/%Y").date()
print(prjtdate)
crntdatetime = datetime.datetime.today()
crntdate = crntdatetime.date()
print(crntdate)
difference = prjtdate - crntdate
print(str(difference.days) + ' days')
weeksRem  = math.floor(difference.days / 7)
daysRem = difference.days % 7
print(str(weeksRem) + ' weeks and ' + str(daysRem) + ' days left')
# Out:
# Enter deadline for project (mm/dd/yyyy)12/08/2024
# 2024-12-08
# 2023-05-15
# 573 days
# 81 weeks and 6 days left

# %%
import datetime

c= datetime.date.today()
print(c)
# Out:
# 2023-05-15

# %%
# Express Shipping

answer = input('Do you need express shipping ?')
if answer == 'yes' :
  print('additional $10 charged')
print('have a nice day')
# Out:
# Do you need express shipping ?no
# have a nice day

# %%
# If statement with numbers
deposit = int(input('Please enter the amount to be depositied '))

if deposit >= 100 :
  print('You get a free toaster. Enjoy ')
else :
    print('You get a free mug. Enjoy ')
print('Have a nice day')
# Out:
# Please enter the amount to be depositied 60
# You get a free mug. Enjoy
# Have a nice day

# %%
# If statement with Boolean variables
deposit = int(input('Please enter the amount to be deposited '))
freeToaster = False
freeTV = False

if deposit >= 1000 :
  freeTV = True

if deposit >= 100 :
  freeToaster = True


if freeTV :
  print('You get a free TV. Enjoy ')
elif freeToaster :
  print('You get a free Toaster. Enjoy')
else :
  print('You get a free mug. Enjoy ')
print('Have a nice day')
# Out:
# Please enter the amount to be deposited 1000
# You get a free TV. Enjoy
# Have a nice day

# %%
# Calculate total cost for a customer

purchAmt = int(input('Enter total cost of purchase '))
totCost = 0

if purchAmt >= 50 :
  totCost = purchAmt
else :
  totCost = purchAmt + 10

print('Total amount to be paid is $' + str(totCost))
# Out:
# Enter total cost of purchase 10
# Total amount to be paid is $20

# %%
from pickle import TRUE
# Calculate Shipping Cost for a customer

cost = int(input('Enter your total cost of order '))
totCost = 0
country = input('Enter your country ').upper()
canada = False

if country == 'CANADA' :
  canada = TRUE

if canada :
  province = input('Enter your province ').upper()
  if province == 'ALBERTA':
    totCost = cost + (cost*0.0005)
  elif province == 'ONTARIO' or province == 'NOVA SCOTIA' or province == 'NEW BRUNSWICK' :
    totCost = cost + (cost * 0.0013)
  else :
    totCost = cost + (cost * 0.0005) + (cost * 0.0006)
else :
  totCost = cost

print(totCost)
# Out:
# Enter your total cost of order 100
# Enter your country canada
# Enter your province ontario
# 100.13

# %% [markdown]
# # Day 2 topics

# %%
# Draw a square

import turtle

turtle.forward(100)
turtle.right(90)
turtle.color('red')
turtle.forward(100)
turtle.right(90)
turtle.forward(100)
turtle.right(90)
turtle.forward(100)

# This code will not work here but in python graphics online compiler (https://trinket.io/turtle)
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-8-461da51a4324> in <cell line: 5>()
#       3 import turtle
#       4
# ----> 5 turtle.forward(100)
#       6 turtle.right(90)
#       7 turtle.color('red')
#
# /usr/lib/python3.10/turtle.py in forward(distance)
#
# /usr/lib/python3.10/turtle.py in __init__(self, shape, undobuffersize, visible)
#    3812                  visible=_CFG["visible"]):
#    3813         if Turtle._screen is None:
# -> 3814             Turtle._screen = Screen()
#    3815         RawTurtle.__init__(self, Turtle._screen,
#    3816                            shape=shape,
#
# /usr/lib/python3.10/turtle.py in Screen()
#    3662     else return the existing one."""
#    3663     if Turtle._screen is None:
# -> 3664         Turtle._screen = _Screen()
#    3665     return Turtle._screen
#    3666
#
# ...

# %%
# Let uer specify the number of sides needed. nest the shape in itself

import turtle

n = int(input('Enter no of sides'))
# turtle.color('red')
for steps in range(n) :
  turtle.forward(10)
  turtle.right(360/n)
  for moresteps in range(n) :
    turtle.forward(5)
    turtle.right(360/n)

# %%
# Ask addition ques to customer and prompt them till they get the answer right

answer = '0'
while answer != '4' :
  # print('Sorry. This is incorrect. Please try again')
  answer = input('What is 2+2 ?')
  

print('Yes, you are correct. Congratulations')
# Out:
# What is 2+2 ?3
# What is 2+2 ?3
# What is 2+2 ?3
# What is 2+2 ?4
# Yes, you are correct. Congratulations

# %%
import turtle
steps = 0

while steps < 4 :
  turtle.forward(100)
  turtle.right(90)
  steps = steps + 1

# %%
# etch a sketch program

import turtle

etch = input('Enter pen color ')
lineLen = int(input('Enter length of line '))
angle = int(input('Enter angle '))
sides = int(input('Number of sides '))

counter = 0 
while counter < sides :
  turtle.color(etch)
  turtle.forward(lineLen)
  turtle.right(angle)
  counter = counter + 1

# %%
numbers = [2, 7, 5, 8, 3]

print(numbers[0])
numbers.append(4)
print(numbers[-1])

numbers.remove(4)
print(numbers[-1])

del numbers[0]
print(numbers[0])

print(numbers.index(7))
# Out:
# 2
# 4
# 3
# 7
# 0

# %%
numbers = [2, 7, 5, 8, 3]
n = len(numbers)
numbers.sort()
for steps in range(n) :
  print(numbers[steps])
# Out:
# 2
# 3
# 5
# 7
# 8

# %%
guestList = []
name = ''

while name != 'done' :
  name = input('Enter name of guest ')
  guestList.append(name)

guestList.remove('done')
n = len(guestList)
guestList.sort()
 
for steps in range(n) :
  print(guestList[steps])
# Out:
# Enter name of guest aparna
# Enter name of guest himanshu
# Enter name of guest done
# aparna
# himanshu

# %% [markdown]
# # Files in Python

# %%
# create file and assign mode to the file

fileName = "guestList.csv"
accessMode = "w"
myFile = open(fileName, accessMode)
data = input('Enter your data ')

myFile.write('data \n')
myFile.close()

print('File written successfully')
# Out:
# Enter your data 123456
# File written successfully

# %%
# Read CSV file
import csv

fileName = "guestlist.csv"
accessMode = "r"

# Automatically close the file
with open(fileName, accessMode) as myCsvFile :
  dataFromFile = csv.reader(myCsvFile)
  # Display the data as a list
  for currentRow in dataFromFile :
    print(currentRow)
    # Display the data as a string, more user friendly format
    for row in currentRow :
      print(row)

# %%
# Read CSV file
import csv

fileName = "guestlist.csv"
accessMode = "r"

# Automatically close the file
with open(fileName, accessMode) as myCsvFile :
  dataFromFile = csv.reader(myCsvFile)
  # Display the data as a string, more user friendly format
  for currentRow in dataFromFile :
    print(',', .join(currentRow))

# %%
#Write program that prints names and ages of guests in the guestlist file

import csv

fileName = 'guestlist.csv'
accessMode = 'w'

with open(fileName, accessMode) as myFile :
  writer = csv.writer(myFile)
  writer.writerow(row)

# %% [markdown]
# # Function

# %%
def main():
  printMsg()
  return

def printMsg():
  print('Hello World')
  return

printMsg()
# Execute the main function
main()
# Out:
# Hello World
# Hello World

# %%
def main():
  printNames()
  return

def printNames() :
  names = ['Aparna', 'Himanshu', 'Hanu', 'Bitto']
  for steps in names :
    print(steps)
  return

main()
# Out:
# Aparna
# Himanshu
# Hanu
# Bitto

# %%
def main():
  name = ['Aparna', 'Himanshu', 'Hanu']
  newName = input('Enter name : ')
  name.append(newName)
  printNames(name)
  return

def printNames(list):
  for steps in list:
    print(steps)
  return

main()
# Out:
# Enter name : bitto
# Aparna
# Himanshu
# Hanu
# bitto

# %%
newName = input ('Enter your name : ')

def getMsg(name):
  message = 'Hello ' + name
  return message

def printMsg(message):
  print(message)
  return

output = getMsg(newName)
printMsg(output)
# Out:
# Enter your name : Aparna
# Hello Aparna

# %% [markdown]
# # Exception Handling

# %%
# Zero division error

firstNumber = float(input('Enter First Number '))
secondNumber = float(input('Enter Second Number '))

try:
  result = int(firstNumber/secondNumber)
  print('the result is '+ str(result))

except:
  print('Sorry. Something went wrong')
# Out:
# Enter First Number 14
# Enter Second Number 6
# the result is 2

# %%
# Find the complete error message
import sys

firstNumber = float(input('Enter First Number '))
secondNumber = float(input('Enter Second Number '))

try:
  result = int(firstNumber/secondNumber)
  print('the result is '+ str(result))

except:
  error = sys.exc_info()[0]
  print('Sorry. Something went wrong')
  print(error)

# Finally always executes irrespective of the code
finally:
  print('All is well')
# Out:
# Enter First Number 10
# Enter Second Number 0
# Sorry. Something went wrong
# <class 'ZeroDivisionError'>
# All is well

# %%
firstNumber = float(input('Enter First Number '))
secondNumber = float(input('Enter Second Number '))

try:
  result = int(firstNumber/secondNumber)
  print('the result is '+ str(result))

except ZeroDivisionError:
 print('The answer is infinity')
# Out:
# Enter First Number 10
# Enter Second Number 0
# The answer is infinity

# %%
# Force my program to exit code if an error occurs an don't want to continue

import sys

firstNumber = float(input('Enter First Number '))
secondNumber = float(input('Enter Second Number '))

try:
  result = int(firstNumber/secondNumber)
  print('the result is '+ str(result))

except ZeroDivisionError:
  print('The answer is infinity')
  sys.exit()
print('this message only displays if there is no error message')

# use variables and an if statement to control what happens after an error
#   errorflag = true
# if not errorflag:
#   print('this message only displays if there is no error message')
# Out:
# Enter First Number 10
# Enter Second Number 5
# the result is 2
# this message only displays if there is no error message

# %% [markdown]
# https://docs.python.org/3/search.html?q=exceptions&check_keywords=yes&area=default
# python exceptions
#
#
# when an error occurs use sys.exc_info() function to get the name of the error

# %%
for steps in range(1,10,2):
	print(steps)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# # Python for Data Science
#
# > Indented block

# %% [markdown]
# Function is a block of code which performs a specific task

# %% [markdown]
# Class is s a template/ blue print for a real world entity (like cellphone). it has properties (like colour , cost) and behaviour (make calls, watch videos)
#
#
# Objects are specific instances of a class.
#
# ex. mobile phone would be a class and its specific objects(instances) would be samsung, apple etc

# %% [markdown]
# Python is known as dynamically typed programming language.
# Datatype of the variable would be considered as the datatype of the variable

# %%
# Find datatype of a variable

x = 'Honey'
type(x)
# Out:
# str

# %% [markdown]
# Types of Operators -
# - Arithmetic
# - logical- and, or,
# - relational - >, <, ==, !=

# %% [markdown]
# Python tokens - smallest meaningful component in a program
# - keywords - special reserved words that provide meaningful insight to a compiler. ex. def, true, false, and, as, none
# - identifiers - names used for functions, variables and objects
# - literals - constants in python. values stored in variable are liternals
# - operators

# %%
# replace substring
name = 'Aparna'
print(name.replace('p','x'))

#count number of occurences of a substring
s = 'what a good, good day'
print(s.count('good'))

# find index of substring
print(s.find('good'))

# split a string
print(s.split(','))
# Out:
# Axarna
# 2
# 7
# ['what a good', ' good day']

# %% [markdown]
# Data Structures in python-
# - tuples - ordered collection of elements enclosed within (). they are immutable i.e. you can't change a value inside the tuple. it is a heterogenous mixture of elements of different datatype
# - list - ordered collection of elements enclosed in []. they are mutable ie. you can change a value inside a list
# - dictionary - unordered collection of key-value pairs enclosed in {}. this is mutable ie. values can be modified
# - set - unordered and unindexed collection of elements enclosed in {}. here duplicates are not allowed

# %%
# tuple

tup1 = (1,'Aparna','himanshu',2, True, False,6,8)
print(tup1)
print(type(tup1))

# first element of tuple
print(tup1[0])

# last element of tuple
print(tup1[-1])

# sequence of elements in the tuple
print(tup1[2:5])

# length of tuple
print(len(tup1))

# concatenate 2 tuple
tup2 =('Shilly','bitto','hanu', 8, 9, 10)
print(tup1+tup2)

# repeatation
print(tup2*4)

# min & max in tuple
tup3=(1,2,3,4,-5)

print(min(tup3))
print(max(tup3))
# Out:
# (1, 'Aparna', 'himanshu', 2, True, False, 6, 8)
# <class 'tuple'>
# 1
# 8
# ('himanshu', 2, True)
# 8
# (1, 'Aparna', 'himanshu', 2, True, False, 6, 8, 'Shilly', 'bitto', 'hanu', 8, 9, 10)
# ('Shilly', 'bitto', 'hanu', 8, 9, 10, 'Shilly', 'bitto', 'hanu', 8, 9, 10, 'Shilly', 'bitto', 'hanu', 8, 9, 10, 'Shilly', 'bitto', 'hanu', 8, 9, 10)
# -5
# 4

# %%
from prompt_toolkit.filters.cli import emacs_selection_mode
# list

l1 = ['aparna','himanshu', 1, 4, 7, 3+5j]
print(l1)
print(type(l1))

# extracting element in list
print(l1[0])
print(l1[-1])
print(l1[2:5])

# modify list
l1[0]='bitto'
print(l1) 

# add additional element in list
l1.append('sparta')
print(l1)

# delete/pop out the last element
l1.pop()
print(l1)

# reverse elements in a list
l1.reverse()
print(l1)

# insert element at a specific index
l1.insert(2,'Aparna')
print(l1)

# sorting a list
l2 = ['apple','banana','pineapple','orange']
l2.sort()
print(l2)

# concatenating lists
print(l1+l2)

# repeating elements in list
print(l2*2)
# Out:
# ['aparna', 'himanshu', 1, 4, 7, (3+5j)]
# <class 'list'>
# aparna
# (3+5j)
# [1, 4, 7]
# ['bitto', 'himanshu', 1, 4, 7, (3+5j)]
# ['bitto', 'himanshu', 1, 4, 7, (3+5j), 'sparta']
# ['bitto', 'himanshu', 1, 4, 7, (3+5j)]
# [(3+5j), 7, 4, 1, 'himanshu', 'bitto']
# [(3+5j), 7, 'Aparna', 4, 1, 'himanshu', 'bitto']
# ['apple', 'banana', 'orange', 'pineapple']
# [(3+5j), 7, 'Aparna', 4, 1, 'himanshu', 'bitto', 'apple', 'banana', 'orange', 'pineapple']
# ['apple', 'banana', 'orange', 'pineapple', 'apple', 'banana', 'orange', 'pineapple']

# %%
# Dictionary

d1={'apple':100, 'banana':30, 'orange':50,'pineapple':80, 'mango':150}
print(d1)
print(type(d1))

# extracting keys
print(d1.keys())

# extracting values
print(d1.values())

# adding a new element
d1['guava']=20
print(d1)

# changing an existing element
d1['apple']=110
print(d1)

# update one dictionary with another
d2 = {'dragonfruit':150,'peach':50}
d1.update(d2)
print(d1)

# deleting/ poping out an element
d1.pop('pineapple')
print(d1)
# Out:
# {'apple': 100, 'banana': 30, 'orange': 50, 'pineapple': 80, 'mango': 150}
# <class 'dict'>
# dict_keys(['apple', 'banana', 'orange', 'pineapple', 'mango'])
# dict_values([100, 30, 50, 80, 150])
# {'apple': 100, 'banana': 30, 'orange': 50, 'pineapple': 80, 'mango': 150, 'guava': 20}
# {'apple': 110, 'banana': 30, 'orange': 50, 'pineapple': 80, 'mango': 150, 'guava': 20}
# {'apple': 110, 'banana': 30, 'orange': 50, 'pineapple': 80, 'mango': 150, 'guava': 20, 'dragonfruit': 150, 'peach': 50}
# {'apple': 110, 'banana': 30, 'orange': 50, 'mango': 150, 'guava': 20, 'dragonfruit': 150, 'peach': 50}

# %%
# set

s1={'Aparna', 'himanshu', 1, 5}
print(s1)
print(type(s1))

# adding an element 
s1.add(6)
print(s1)

# add muliple elements
s1.update(["bitto","hanu", 7])
print(s1)

# remove an element
s1.remove('Aparna')
print(s1)

# union/concatenate 2 sets
s2 = {'a','b','c'}
s1.union(s2)

# intersection of 2 sets
s3= {1,6, 7, 0, 8}
s1.intersection(s3)
# Out:
# {1, 'Aparna', 'himanshu', 5}
# <class 'set'>
# {1, 'himanshu', 5, 6, 'Aparna'}
# {'bitto', 1, 'himanshu', 5, 6, 7, 'hanu', 'Aparna'}
# {'bitto', 1, 'himanshu', 5, 6, 7, 'hanu'}
# {1, 6, 7}

# %%
# Find if an element is present in tuple

tup1 = (1, 2, 3)

if 6 in tup1:
  print('it is a part of tuple')
else:
  print('it is not a part of tuple')

# similar code can be used in list
# Out:
# it is not a part of tuple

# %%
# find is a value is present in list. if yes then update it

l1 = [1,2,3,4,5,6,7,8]

if l1[2]==3:
  l1[2]=l1[2]+5

print(l1)
# Out:
# [1, 2, 8, 4, 5, 6, 7, 8]

# %%
# if with dictionary

d1={'apple':100, 'banana':30, 'orange':50,'pineapple':80, 'mango':150}

if d1['banana']==30:
  d1['banana']= d1['banana']+30

print(d1)
# Out:
# {'apple': 100, 'banana': 60, 'orange': 50, 'pineapple': 80, 'mango': 150}

# %%
# Print table of 2 whith while loop

i=1

while i<=10:
  print('2 * '+ str(i) + " = " + str(2*i))
  i=i+1
# Out:
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 2 * 10 = 20

# %%
# Check if a number is even or odd

num = int(input('Enter the number '))

if num%2==0:
  print('this number is even')
else:
  print('this number is odd')
# Out:
# Enter the number 5
# this number is odd

# %%
# check if a number is positive, negative or zero

num = int(input('Enter the number '))

if num>0:
  print('this is a positive number')
elif num==0:
  print('this is zero')
else:
  print('this is a negative number')
# Out:
# Enter the number -6
# this is a negative number

# %%
# find factorial of a number

num = int(input('Enter the number '))
i=1

if num<0:
  print('we cannot calculate the factorial of this number')
elif num==0:
  print('the factorial of zero is always 1')
else:
  for steps in range(1,num+1):
    i=i*steps
  print(i)
# Out:
# Enter the number 5
# 120

# %%
# reversing a number

num = int(input('Enter a number '))
rev=0

while num>0:
  digit=num%10
  rev=rev*10+digit
  num=num//10
print('reverse of the number is ' + str(rev))
# Out:
# Enter a two digit number 12345678
# reverse of the number is 87654321

# %%
# Check if number is a palindrome

num = int(input('Enter a number '))
temp= num
rev = 0

while (num>0):
  digit = num%10
  rev= rev*10+digit
  num=num//10

if temp==rev:
  print('this number is a palindrome')
else:
  print('this number is not a palindrome')
# Out:
# Enter a number 1234567654321
# this number is a palindrome

# %%
# fibonacci series

n=int(input('Enter the number '))
a=0
b=1


if n<0:
  print('we cannot determine the fibonacci series')
elif n==0:
  print('this cannot be performed')
elif n==1:
  print(a)
else:
  for steps in range(2,n):
    c=a+b
    a=b
    b=c
  print(b)
# Out:
# Enter the number 7
# 8

# %% [markdown]
# Functions - a block of code that performs a particular tasks.
# Types -
# - Normal Function
#         def function name:
#           execute statement
# - Lambda Function
#         lambda arguments : expression

# %%
# Normal Function

def helloworld():
  print('Hello world!!')

helloworld()
# Out:
# Hello world!!

# %%
# Function with Parameter

def para(x):
  return x+10

para(100)
# Out:
# 110

# %%
# Function to check even and odd number

def check(x):
  if x%2 == 0 :
    print('This is an even number')
  else:
    print('This is a odd number')

num= int(input('Enter the number here: '))
check(num)
# Out:
# Enter the number here: 7
# This is a odd number

# %%
# Function to find cube for a number

def cube(x):
  cub= x**3
  return cub

num= int(input('Enter the number here: '))
cube(num)
# Out:
# Enter the number here: 5
# 125

# %%
# Find cube of a number using Lambda function

num= int(input('Enter the number here: '))
g= lambda x:x**3
print(g(num))
# Out:
# Enter the number here: 5
# 125

# %%
# Find all even numbers in a list
# Lambda function with filter

l1 = [6, 4, 68, 89, 9, 24, 45]
final_l1= list(filter(lambda x:(x%2==0), l1))
print(final_l1)
# Out:
# [6, 4, 68, 24]

# %%
# Find square of all numbers in a list
# Lambda with map

l1 = [6, 4, 68, 89, 9, 24, 45]
final_l1 = list(map(lambda x: (x**2), l1))
print(final_l1)
# Out:
# [36, 16, 4624, 7921, 81, 576, 2025]

# %%
# Add all values in a list

from functools import reduce
l1 = [6, 4, 68, 89, 9, 24, 45]
sum= reduce((lambda x,y : x+y),l1)
print(sum)
# Out:
# 245

# %% [markdown]
# Python Object- oriented programming (oops)-
#
# concepts -
# - classes - template/blueprint for real world entities.ex phone. it has properties/ attributes (color, cost) and behaviour/ methods (make calls, watch videos)
#   it is a user defined datatype
# - objects - specific instances of a class. ex. different brands of phone(samsung, apple)

# %%
# Class

# Creating a phone class. 
# Always the first letter of class name is in capital

class Phone:

  def make_calls(self): #self is a referencing call. all methods should have self as the first parameter
    print('Making a call')
  
  def play_games(self):
    print('playing a game')

# Instantiating in p1 object
p1=Phone()

# Invoking methods through object
p1.make_calls()

p1.play_games()
# Out:
# Making a call
# playing a game

# %%
# Adding new parameters to our methods

class Phone:

  def set_color(self, color):
    self.color=color
  
  def set_cost(self, cost):
    self.cost=cost
  
  def show_color(self):
    return self.color

  def show_cost(self):
    return self.cost

p1=Phone()

p1.set_color('blue')
p1.set_cost(500)

p1.show_color()
# p1.show_cost()
# Out:
# 'blue'

# %% [markdown]
# Constructor - speical type of function with which you can assign values for all of the attributes

# %%
# Creating a class with constructor 

class Employee:

  def __init__ (self, name, age, salary, gender): #init method acts as a contructor
    self.name = name
    self.age = age
    self.salary = salary
    self.gender = gender
  
  def employee_details(self):
    print('Name of employee is ', self.name)
    print('Age of employee is', self.age)
    print('Salary of employee is ', self.salary)
    print('Gender of employee is ', self.gender)

e1=Employee('Aparna', 30, 100000, 'Female')

e1.employee_details()
# Out:
# Name of employee is  Aparna
# Age of employee is 30
# Salary of employee is  100000
# Gender of employee is  Female

# %% [markdown]
# Inheritance - with this one class can derive the properties of another class

# %%
# Inheritance

#Base Class

class Vehicle:

  def __init__(self, mileage, cost):
    self.mileage = mileage
    self.cost = cost

  def show_details(self):
    print('I am a vehicle')
    print('Mileage of the vehicle is ', self.mileage)
    print('cost of the vehicle is ', self.cost)

v1=Vehicle(30,10000)

v1.show_details()

#inherited class
class Car(Vehicle):

  def show_car_details(self):
    print('I am a car')

c1= Car(40, 15000)

c1.show_details()
c1.show_car_details()
# Out:
# I am a vehicle
# Mileage of the vehicle is  30
# cost of the vehicle is  10000
# I am a vehicle
# Mileage of the vehicle is  40
# cost of the vehicle is  15000
# I am a car

# %%
# Over-riding the init method

class Vehicle:

  def __init__(self, mileage, cost):
    self.mileage = mileage
    self.cost = cost

  def show_details(self):
    print('I am a vehicle')
    print('Mileage of the vehicle is ', self.mileage)
    print('cost of the vehicle is ', self.cost)

# v1=Vehicle(30,10000)

# v1.show_details()

#inherited class
class Car(Vehicle):

  def __init__(self, mileage, cost, tyres, hp):
    super().__init__(mileage, cost) #over-riding the init method
    self.tyres = tyres
    self.hp = hp

  def show_car_details(self):
    print('I am a car')
    print('the number of tyres are ', self.tyres)
    print('the hp is ', self.hp)

c1= Car(40, 15000, 4, 200)

c1.show_details()
c1.show_car_details()
# Out:
# I am a vehicle
# Mileage of the vehicle is  40
# cost of the vehicle is  15000
# I am a car
# the number of tyres are  4
# the hp is  200

# %% [markdown]
# Types of Inheritance -
# - Single Inheritance - one class inherits the properties of another class
# - Multiple Inheritance - child inherits from more than one parent class
# - Multi-level Inheritance - we have a parent, child and grand-child relationship
# - Hybrid Inheritance

# %%
# Multiple Inheritance

# parent classes
class Parent1:

  def assign_str1(self, str1):
    self.str1=str1
  
  def show_str1(self):
    return self.str1

class Parent2:

  def assign_str2(self, str2):
    self.str2=str2
  
  def show_str2(self):
    return self.str2

# Child class

class Child(Parent1,Parent2):

  def assign_str3(self, str3):
    self.str3 = str3
  
  def show_str3(self):
    return self.str3

c1=Child()

c1.assign_str1('hello')
c1.assign_str2('How are you doing?')
c1.assign_str3('Wassup')

# c1.show_str1()
c1.show_str2()
# c1.show_str3()
# Out:
# 'How are you doing?'

# %%
# Multi-level Inheritance

class Parent:
  
  def assign_name(self, name):
    self.name = name
  
  def show_name(self):
    return self.name

class Child(Parent):

  def assign_age(self, age):
    self.age = age
  
  def show_age(self):
    return self.age

class Grandchild(Child):

  def assign_gender(self, gender):
    self.gender = gender
  
  def show_gender(self):
    return self.gender

g1= Grandchild()

g1.assign_name('Aparna')
g1.show_name()

g1.assign_age(30)
g1.show_age()

g1.assign_gender('Female')
g1.show_gender()
# Out:
# 'Female'

# %% [markdown]
# <!-- Inheritance in python -->
